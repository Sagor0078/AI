# %% [markdown]
# <a href="https://colab.research.google.com/github/Sagor0078/AI/blob/main/cat_dog_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 607.6/607.6 kB 5.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 70.0MB/s]

# %%
results = model.predict("/content/drive/MyDrive/object_detection/cat_dog.jpg")
# Out:
# image 1/1 /content/drive/MyDrive/object_detection/cat_dog.jpg: 448x640 1 cat, 1 dog, 1164.8ms
# Speed: 15.6ms preprocess, 1164.8ms inference, 31.6ms postprocess per image at shape (1, 3, 448, 640)

# %%
result = results[0]
print(len(result.boxes))
# Out:
# 2

# %%
box = result.boxes[0]

# %%
# print("Object type:", box.cls)
# print("Coordinates:", box.xyxy)
# print("Probability:", box.conf)

# %%
# print("Object type:",box.cls[0])
# print("Coordinates:",box.xyxy[0])
# print("Probability:",box.conf[0])

# %%
# cords = box.xyxy[0].tolist()
# class_id = box.cls[0].item()
# conf = box.conf[0].item()
# print("Object type:", class_id)
# print("Coordinates:", cords)
# print("Probability:", conf)

# %%
# print(result.names)

# %%
# cords = box.xyxy[0].tolist()
# cords = [round(x) for x in cords]
# class_id = result.names[box.cls[0].item()]
# conf = round(box.conf[0].item(), 2)
# print("Object type:", class_id)
# print("Coordinates:", cords)
# print("Probability:", conf)

# %%
# for box in result.boxes:
#   class_id = result.names[box.cls[0].item()]
#   cords = box.xyxy[0].tolist()
#   cords = [round(x) for x in cords]
#   conf = round(box.conf[0].item(), 2)
#   print("Object type:", class_id)
#   print("Coordinates:", cords)
#   print("Probability:", conf)
#   print("---")

# %%
for box in result.boxes:
  label = result.names[box.cls[0].item()]
  cords = [round(x) for x in box.xyxy[0].tolist()]
  prob = box.conf[0].item()
  print('Object type',label)
  print('Coordinates',cords)
  print('Probability',prob)
# Out:
# Object type dog
# Coordinates [261, 94, 461, 314]
# Probability 0.9449875354766846
# Object type cat
# Coordinates [140, 170, 256, 315]
# Probability 0.91309654712677

# %%
from PIL import Image
Image.fromarray(result.plot()[:,:,::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=612x415 at 0x7BB7CE520790>
